# %% [markdown]
# # Week 1.4: Prompt Engineering for Digital Twins
#
# ## Learning Objectives
# - Master different prompting techniques
# - Understand zero-shot, few-shot, and chain-of-thought
# - Apply prompting to digital twin interactions
#
# ## Key Insight
# > 'Moving from Chat to System Instructions'

# %%
import numpy as np
import matplotlib.pyplot as plt
from typing import List, Dict

print('✅ Ready for prompting exercises!')

# %% [markdown]
# ## Part 1: Prompting Fundamentals
#
# ### 1.1 Zero-Shot Prompting

# %%
# Example prompts for digital twin
zero_shot_examples = [
    {
        'task': 'activity_prediction',
        'prompt': 'Predict the next activity: I just finished work, had dinner, and now...',
        'expected': 'leisure/relaxation activity'
    },
    {
        'task': 'preference_extraction',
        'prompt': 'Extract preferences from: I love outdoor activities but hate crowded places',
        'expected': {'likes': ['outdoor', 'quiet'], 'dislikes': ['crowds']}
    }
]

print('Zero-Shot Examples:')
for ex in zero_shot_examples:
    print(f"\nTask: {ex['task']}")
    print(f"Prompt: {ex['prompt']}")
    print(f"Expected: {ex['expected']}")

# %% [markdown]
# ### 🎯 Exercise 1.1 (Easy): Create Your Prompts
#
# **Task**: Design prompts for your digital twin use case.

# %%
print("My Digital Twin Prompts:")
print("=" * 70)
for i, ex in enumerate(my_prompts, 1):
    print(f"\n{i}. Task: {ex['task']}")
    print(f"   Prompt: {ex['prompt']}")
    print(f"   Expected: {ex['expected']}")
# Out:
# My Digital Twin Prompts:
# ======================================================================
#
# 1. Task: mood_inference
#    Prompt: Based on this message, what is the user's mood? "Ugh, Mondays. I really don't want to go to work today."
#    Expected: negative/low-energy mood (tired, reluctant)
#
# 2. Task: recommendation
#    Prompt: The user likes hiking, reading sci-fi, and cooking Italian food. Suggest one activity for Saturday afternoon.
#    Expected: A recommendation matching at least one interest (e.g., "Try a new hiking trail")
#
# 3. Task: routine_prediction
#    Prompt: User wakes at 6am, exercises, then has coffee. What do they do next on a typical workday?
#    Expected: Get ready for work / commute / start work
#
# 4. Task: sentiment_classification
#    Prompt: Classify as positive, negative, or neutral: "The new restaurant was okay, nothing special."
#    Expected: neutral (slightly negative-leaning)
#
# 5. Task: intent_detection
#    Prompt: What does the user want? "Can you remind me to call mom at 7pm?"
#    Expected: Set a reminder for 7pm to call mom
#
# 6. Task: personalized_response
#    Prompt: User loves jazz music and hates small talk. They just got promoted. Write a 1-sentence congratulations.
#    Expected: Brief, sincere congrats without fluff (e.g., "Congrats — that's huge. Celebrating with some jazz tonight?")
